# %% [markdown]
# <i>Copyright (c) Recommenders contributors.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Neural Collaborative Filtering
#
# Neural Collaborative Filtering (NCF) is a well known recommendation algorithm that generalizes the matrix factorization problem with multi-layer perceptron.
#
# This notebook provides an example of how to utilize and evaluate NCF implementation in the `recommenders`. We use a smaller dataset in this example to run NCF efficiently with GPU acceleration.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import pandas as pd
import tensorflow as tf
# tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.utils.timer import Timer
from recommenders.models.ncf.ncf_singlenode import NCF
from recommenders.models.ncf.dataset import Dataset as NCFDataset
from recommenders.datasets.python_splitters import python_random_split
from recommenders.evaluation.python_evaluation import (
    map, ndcg_at_k, precision_at_k, recall_at_k
)
from recommenders.utils.notebook_utils import store_metadata

from datasets import outfits

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# WARNING:tensorflow:From c:\Users\zivil\Desktop\ND\cat-website\daily-outfit-recommender\recommenders\models\ncf\ncf_singlenode.py:12: The name tf.disable_eager_execution is deprecated. Please use tf.compat.v1.disable_eager_execution instead.
#
# System version: 3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]
# Pandas version: 2.3.3
# Tensorflow version: 2.20.0
# c:\Users\zivil\anaconda3\envs\outfit\lib\site-packages\pandera\_pandas_deprecated.py:160: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)

# %% [markdown]
# Set the default parameters.

# %%
# top k items to recommend
TOP_K = 10

# Change data size as appropriate
OUTFITS_DATA_SIZE = '200'

# Model parameters
EPOCHS = 100
BATCH_SIZE = 256

SEED = 42

# %% [markdown]
# ### 1. Download the dataset

# %%
# df = outfits.load_pandas_df(
#     header=["UserId", "Weather", "Clothing", "Event", "Season"],
#     filepath=f"datasets/csv/own_feature2.csv"
# )
# df['ClothingId'] = df['Clothing'].astype('category').cat.codes
# print(df)

df = pd.read_csv("datasets/csv/own_feature2.csv")
df['ClothingId'] = df['Clothing'].astype('category').cat.codes

print(df)
# Out:
#      UserId Weather Clothing          Event  Season  Rating  ClothingId
# 0         1   Sunny  T-shirt  Casual Outing  Summer     5.0          11
# 1         1     Hot   Shorts       Exercise  Summer     4.0           8
# 2         1   Rainy   Hoodie         School    Fall     3.0           2
# 3         1    Cold   Jacket         Travel  Winter     4.0           3
# 4         1   Sunny  Sweater   Family Event  Spring     5.0          10
# ..      ...     ...      ...            ...     ...     ...         ...
# 198      24     Hot   Hoodie         School  Summer     5.0           2
# 199      24   Sunny  T-shirt  Casual Outing  Spring     5.0          11
# 200      24    Cold    Pants           Work  Winter     4.0           6
# 201      24   Windy   Hoodie         School  Winter     4.0           2
# 202      24   Sunny   Shorts          Beach  Summer     5.0           8
#
# [203 rows x 7 columns]

# %% [markdown]
# ### 2. Split the data using the Spark splitter provided in utilities

# %%
train, test = python_random_split(
    df, 
    ratio=0.75
)
train = train[train['Rating'] > 0]
assert len(train) > 0, "STOP: Training set is empty immediately after splitting."

# %% [markdown]
# Filter out any users or items in the test set that do not appear in the training set.

# %%
test = test[test["UserId"].isin(train["UserId"].unique())]
test = test[test["ClothingId"].isin(train["ClothingId"].unique())]

train_sorted = train.sort_values(by="UserId")
test_sorted = test.sort_values(by="UserId")

# %% [markdown]
# Write datasets to csv files.

# %%
train_file = "./train.csv"
test_file = "./test.csv"
train_sorted.to_csv(train_file, index=False)
test_sorted.to_csv(test_file, index=False)

# %% [markdown]
# Generate an NCF dataset object from the data subsets.

# %%
data = NCFDataset(
  train_file=train_file, 
  test_file=test_file, 
  seed=SEED, 
  col_user="UserId", 
  col_item="ClothingId", 
  col_rating="Rating")

assert data.n_users > 0 and data.n_items > 0, "STOP: The NCFDataset object loaded no users or items."
# Out:
# INFO:recommenders.models.ncf.dataset:Indexing ./train.csv ...
# INFO:recommenders.models.ncf.dataset:Indexing ./test.csv ...
# INFO:recommenders.models.ncf.dataset:Indexing ./test_full.csv ...

# %% [markdown]
# ### 3. Train the NCF model on the training data, and get the top-k recommendations for our testing data
#
# NCF accepts implicit feedback and generates prospensity of items to be recommended to users in the scale of 0 to 1. A recommended item list can then be generated based on the scores. Note that this quickstart notebook is using a smaller number of epochs to reduce time for training. As a consequence, the model performance will be slighlty deteriorated.

# %%
model = NCF (
    n_users=data.n_users, 
    n_items=data.n_items,
    model_type="NeuMF",
    n_factors=4,
    layer_sizes=[16,8,4],
    n_epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    learning_rate=1e-3,
    verbose=1,
    seed=SEED
)
# Out:
# WARNING:tensorflow:From c:\Users\zivil\Desktop\ND\cat-website\daily-outfit-recommender\recommenders\models\ncf\ncf_singlenode.py:264: The name tf.losses.log_loss is deprecated. Please use tf.compat.v1.losses.log_loss instead.
# c:\Users\zivil\anaconda3\envs\outfit\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From c:\Users\zivil\Desktop\ND\cat-website\daily-outfit-recommender\recommenders\models\ncf\ncf_singlenode.py:264: The name tf.losses.log_loss is deprecated. Please use tf.compat.v1.losses.log_loss instead.
# WARNING:tensorflow:From c:\Users\zivil\Desktop\ND\cat-website\daily-outfit-recommender\recommenders\models\ncf\ncf_singlenode.py:269: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From c:\Users\zivil\Desktop\ND\cat-website\daily-outfit-recommender\recommenders\models\ncf\ncf_singlenode.py:269: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %%
with Timer() as train_time:
    model.fit(data)

print(model)
print("Took {} seconds for training.".format(train_time))
# Out:
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 1 [0.26s]: train_loss = 0.693041
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 2 [0.02s]: train_loss = 0.692855
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 3 [0.02s]: train_loss = 0.692803
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 4 [0.02s]: train_loss = 0.692630
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 5 [0.02s]: train_loss = 0.692366
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 6 [0.02s]: train_loss = 0.692062
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 7 [0.02s]: train_loss = 0.691922
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 8 [0.02s]: train_loss = 0.691633
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 9 [0.03s]: train_loss = 0.691147
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 10 [0.03s]: train_loss = 0.690847
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 11 [0.02s]: train_loss = 0.690568
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 12 [0.02s]: train_loss = 0.690072
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 13 [0.02s]: train_loss = 0.690084
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 14 [0.02s]: train_loss = 0.689445
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 15 [0.02s]: train_loss = 0.689210
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 16 [0.03s]: train_loss = 0.688808
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 17 [0.04s]: train_loss = 0.689017
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 18 [0.03s]: train_loss = 0.688303
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 19 [0.02s]: train_loss = 0.688318
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 20 [0.02s]: train_loss = 0.687564
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 21 [0.02s]: train_loss = 0.687510
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 22 [0.02s]: train_loss = 0.686833
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 23 [0.02s]: train_loss = 0.686693
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 24 [0.02s]: train_loss = 0.685865
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 25 [0.02s]: train_loss = 0.685662
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 26 [0.02s]: train_loss = 0.685007
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 27 [0.02s]: train_loss = 0.684538
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 28 [0.02s]: train_loss = 0.685037
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 29 [0.02s]: train_loss = 0.684133
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 30 [0.02s]: train_loss = 0.682893
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 31 [0.02s]: train_loss = 0.682793
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 32 [0.02s]: train_loss = 0.682960
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 33 [0.02s]: train_loss = 0.681229
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 34 [0.02s]: train_loss = 0.682031
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 35 [0.02s]: train_loss = 0.681552
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 36 [0.02s]: train_loss = 0.680529
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 37 [0.02s]: train_loss = 0.679961
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 38 [0.03s]: train_loss = 0.679887
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 39 [0.04s]: train_loss = 0.679792
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 40 [0.02s]: train_loss = 0.677973
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 41 [0.02s]: train_loss = 0.678035
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 42 [0.02s]: train_loss = 0.677645
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 43 [0.02s]: train_loss = 0.677102
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 44 [0.02s]: train_loss = 0.674961
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 45 [0.02s]: train_loss = 0.674888
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 46 [0.02s]: train_loss = 0.674806
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 47 [0.02s]: train_loss = 0.673640
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 48 [0.02s]: train_loss = 0.673361
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 49 [0.02s]: train_loss = 0.672435
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 50 [0.02s]: train_loss = 0.671555
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 51 [0.02s]: train_loss = 0.670500
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 52 [0.02s]: train_loss = 0.671897
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 53 [0.02s]: train_loss = 0.670653
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 54 [0.03s]: train_loss = 0.670156
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 55 [0.03s]: train_loss = 0.669827
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 56 [0.02s]: train_loss = 0.667385
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 57 [0.02s]: train_loss = 0.667880
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 58 [0.02s]: train_loss = 0.665367
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 59 [0.02s]: train_loss = 0.667761
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 60 [0.02s]: train_loss = 0.667370
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 61 [0.02s]: train_loss = 0.664310
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 62 [0.02s]: train_loss = 0.661455
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 63 [0.02s]: train_loss = 0.663020
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 64 [0.02s]: train_loss = 0.662709
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 65 [0.02s]: train_loss = 0.661021
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 66 [0.02s]: train_loss = 0.660073
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 67 [0.02s]: train_loss = 0.660345
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 68 [0.02s]: train_loss = 0.657681
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 69 [0.02s]: train_loss = 0.657405
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 70 [0.02s]: train_loss = 0.657029
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 71 [0.02s]: train_loss = 0.653822
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 72 [0.02s]: train_loss = 0.653710
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 73 [0.02s]: train_loss = 0.654415
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 74 [0.02s]: train_loss = 0.653020
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 75 [0.02s]: train_loss = 0.653023
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 76 [0.02s]: train_loss = 0.653235
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 77 [0.02s]: train_loss = 0.647521
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 78 [0.02s]: train_loss = 0.646360
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 79 [0.02s]: train_loss = 0.644789
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 80 [0.02s]: train_loss = 0.643925
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 81 [0.02s]: train_loss = 0.644906
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 82 [0.02s]: train_loss = 0.647185
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 83 [0.02s]: train_loss = 0.642414
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 84 [0.02s]: train_loss = 0.646394
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 85 [0.02s]: train_loss = 0.642519
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 86 [0.02s]: train_loss = 0.641594
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 87 [0.02s]: train_loss = 0.640051
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 88 [0.02s]: train_loss = 0.637108
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 89 [0.02s]: train_loss = 0.634336
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 90 [0.02s]: train_loss = 0.634684
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 91 [0.02s]: train_loss = 0.633065
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 92 [0.02s]: train_loss = 0.633187
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 93 [0.02s]: train_loss = 0.630706
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 94 [0.02s]: train_loss = 0.635511
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 95 [0.02s]: train_loss = 0.626942
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 96 [0.02s]: train_loss = 0.624965
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 97 [0.02s]: train_loss = 0.626975
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 98 [0.02s]: train_loss = 0.625887
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 99 [0.02s]: train_loss = 0.625500
# INFO:recommenders.models.ncf.ncf_singlenode:Epoch 100 [0.02s]: train_loss = 0.621527
# <recommenders.models.ncf.ncf_singlenode.NCF object at 0x000001A3767BBFA0>
# Took 2.4315 seconds for training.

# %%
with Timer() as test_time:
    users, items, preds = [], [], []
    item = list(train.ClothingId.unique())
    for user in train.UserId.unique():
        user = [user] * len(item) 
        users.extend(user)
        items.extend(item)
        preds.extend(list(model.predict(user, item, is_list=True)))

    all_predictions = pd.DataFrame(data={"UserId": users, "ClothingId":items, "prediction":preds})

    merged = pd.merge(train, all_predictions, on=["UserId", "ClothingId"], how="outer")
    all_predictions = merged[merged.Rating.isnull()].drop('Rating', axis=1)

print("Took {} seconds for prediction.".format(test_time))


print(all_predictions)
# Out:
# Took 0.0464 seconds for prediction.
#      UserId Weather Clothing  ClothingId  prediction
# 1         1     NaN      NaN           1    0.491099
# 4         1     NaN      NaN           3    0.615275
# 5         1     NaN      NaN           4    0.558853
# 8         1     NaN      NaN           7    0.550855
# 11        1     NaN      NaN           9    0.447569
# ..      ...     ...      ...         ...         ...
# 271      20     NaN      NaN           5    0.369384
# 272      20     NaN      NaN           6    0.430236
# 274      20     NaN      NaN           8    0.523288
# 275      20     NaN      NaN           9    0.374776
# 276      20     NaN      NaN          10    0.572345
#
# [128 rows x 5 columns]

# %% [markdown]
# ### 4. Evaluate how well NCF performs

# %% [markdown]
# The ranking metrics are used for evaluation.

# %%
eval_map = map(test, all_predictions, col_prediction='prediction', k=TOP_K, col_user='UserId', col_item='ClothingId')
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K, col_user='UserId', col_item='ClothingId', col_rating='Rating')
eval_precision = precision_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K, col_user='UserId', col_item='ClothingId')
eval_recall = recall_at_k(test, all_predictions, col_prediction='prediction', k=TOP_K, col_user='UserId', col_item='ClothingId')

print("MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall, sep='\n')
# Out:
# MAP:	0.494918
# NDCG:	0.621373
# Precision@K:	0.172222
# Recall@K:	0.618519

# %%
# # Record results for tests - ignore this cell
# store_metadata("map", eval_map)
# store_metadata("ndcg", eval_ndcg)
# store_metadata("precision", eval_precision)
# store_metadata("recall", eval_recall)
# store_metadata("train_time", train_time.interval)
# store_metadata("test_time", test_time.interval)
